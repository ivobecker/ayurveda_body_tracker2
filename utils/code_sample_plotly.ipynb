# %% [markdown]
# #Welcome to the Yupiter Notebooks in vscode

# %%
#Hello World

msg = "hello world"
print(msg)
# Out:
# hello world

# %%
import plotly.express as px

fig = px.scatter(
    data, 
    x="Kilometer", 
    y="Price", 
    hover_data=["Model"],  # Show the model when hovering
    title="Car Price vs. Kilometers Driven",
    labels={"Kilometer": "Kilometers Driven", "Price": "Price (in USD)"}
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import plotly.express as px
#       3 fig = px.scatter(
# ----> 4     data,
#       5     x="Kilometer",
#       6     y="Price",
#       7     hover_data=["Model"],  # Show the model when hovering
#       8     title="Car Price vs. Kilometers Driven",
#       9     labels={"Kilometer": "Kilometers Driven", "Price": "Price (in USD)"}
#      10 )
#      11 fig.show()
#
# NameError: name 'data' is not defined

# %%
print("shift enter")
