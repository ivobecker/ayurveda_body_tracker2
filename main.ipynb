# %%
import json
from models.config import AyurvedaConfig
from loaders.ayurveda import load_ayurveda_config

config = AyurvedaConfig.model_validate(load_ayurveda_config("data/ayurveda_config.json"))
config.haut.attributes_by_dosha.Vata

print(config.haut.attributes_by_dosha.Pitta)
# Out:
# ['warm', 'leicht ölig feucht', 'weich', 'rosafarben', 'Muttermale, Sommersprossen', 'Neigung zu faltiger Haut', 'Pickel']
