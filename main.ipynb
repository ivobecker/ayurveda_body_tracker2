# %%
import json
from models.config import AyurvedaConfig, validate_user_input
from loaders.ayurveda import load_ayurveda_config



config = AyurvedaConfig.model_validate(load_ayurveda_config("data/ayurveda_config.json"))




print(config)

# # Create an instance of UserInput using validate_user_input() function
# input_data = {
#     "koerperbau": {
#     "name": "test",
#     "description": "This is a test input for AyurvedaConfig",
   
#         "attributes_by_dosha": {
#             "Vata": ["warm"],
#             "Pitta": ["hot", "sharp", "oily"],
#             "Kapha": ["heavy", "slow", "cool"]
#         },
#     },
#    "haut": {
#         "name": "test",
#         "description": "This is a test input for AyurvedaConfig",
#         "attributes_by_dosha": {
#             "Vata": ["warm", "dry", "cold"],
#             "Pitta": ["hot", "sharp", "oily"],
#             "Kapha": ["heavy", "slow", "cool"]
#         },
#         "symptoms_by_dosha": {
#             "Vata": ["rough skin", "dryness"],
#             "Pitta": ["redness", "inflammation"]
#             },
#           "allergies_by_dosha": {}
#     }
# }

# input_data2 = '''
# {
#     "koerperbau": {
#     "name": "test",
#     "description": "This is a test input for AyurvedaConfig",
   
#         "attributes_by_dosha": {
#             "Vata": ["warm"],
#             "Pitta": ["hot", "sharp", "oily"],
#             "Kapha": ["heavy", "slow", "cool"]
#         },
#     },
#    "haut": {
#         "name": "test",
#         "description": "This is a test input for AyurvedaConfig",
#         "attributes_by_dosha": {
#             "Vata": ["warm", "dry", "cold"],
#             "Pitta": ["hot", "sharp", "oily"],
#             "Kapha": ["heavy", "slow", "cool"]
#         },
#         "symptoms_by_dosha": {
#             "Vata": ["rough skin", "dryness"],
#             "Pitta": ["redness", "inflammation"]
#             },
#           "allergies_by_dosha": {}
#     }
# }
# '''
# user_input = validate_user_input(input_data)

#user_input2 = AyurvedaConfig.model_validate_json(input_data2)
#print(user_input2.model_dump_json(indent=2))
# Out:
# koerperbau=BaseDoshaSection(name='Körperbau und Erscheinungsbild', description='Beschreibt den allgemeinen Körperbau und das Erscheinungsbild einer Person basierend auf den Dosha-Typen Vata, Pitta und Kapha.', attributes_by_dosha=DoshaMap(Vata=['dünn', 'hervorstehende Knochen, Sehnen und Adern', 'nicht gut aussehend, unbeeindruckendes Äusseres'], Pitta=['mittelgroß', 'wohlgeformt, athletisch', 'attraktives Aussehen'], Kapha=['kräftig, stämmig', 'weiche, abgerundete Körperformen', 'ansehnliches, angenehmes Äusseres']), scoring_by_dosha=DoshaScoring(Vata=1, Pitta=2, Kapha=3)) haut=HautSection(name='Haut', description='Beschreibt die Hautmerkmale und -eigenschaften basierend auf den Dosha-Typen Vata, Pitta und Kapha.', attributes_by_dosha=DoshaMap(Vata=['trocken', 'rau', 'rissig'], Pitta=['warm', 'leicht ölig feucht', 'weich', 'rosafarben', 'Muttermale, Sommersprossen', 'Neigung zu faltiger Haut', 'Pickel'], Kapha=['dick', 'feucht ölig', 'kalt', 'weich', 'glatt']), hautfaerbung_by_dosha=DoshaMap(Vata=['dunkel', 'braun', 'matt'], Pitta=['rosafarben', 'kupferfarben', 'rötlich', 'leicht gebräunt'], Kapha=['hell', 'weisslich']), symptoms_by_dosha=DoshaMap(Vata=['no symptoms'], Pitta=['Eiterung', 'Entzündung', 'Ekzeme', 'Blasenbildung'], Kapha=['Juckreiz']), allergies_by_dosha=DoshaMap(Vata=['no allergies'], Pitta=['Hautrötungen', 'Entzündungen', 'Juckreiz'], Kapha=['vermehrter Schleimbildung', 'Schwellungen']))
